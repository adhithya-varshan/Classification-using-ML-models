# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data = pd.read_csv("diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
corr = data.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,cbar=True,square=True,fmt='.1f',annot=True,cmap='Reds')

# %%
corr_matrix["Outcome"].sort_values(ascending = False)
# Out:
# Outcome                     1.000000
# Glucose                     0.466581
# BMI                         0.292695
# Age                         0.238356
# Pregnancies                 0.221898
# DiabetesPedigreeFunction    0.173844
# Insulin                     0.130548
# SkinThickness               0.074752
# BloodPressure               0.065068
# Name: Outcome, dtype: float64

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.boxplot(data = data)

# %%
Q1 = data['Insulin'].quantile(0.25)
Q3 = data['Insulin'].quantile(0.75)
IQR = Q3 - Q1
whisker_width = 1.5
in_outliers = data[(data['Insulin'] < Q1 - whisker_width*IQR) | (data['Insulin'] > Q3 + whisker_width*IQR)]
in_outliers
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8              2      197             70             45      543  30.5
# 13             1      189             60             23      846  30.1
# 54             7      150             66             42      342  34.7
# 111            8      155             62             26      495  34.0
# 139            5      105             72             29      325  36.9
# 153            1      153             82             42      485  40.6
# 186            8      181             68             36      495  30.1
# 220            0      177             60             29      478  34.6
# 228            4      197             70             39      744  36.7
# 231            6      134             80             37      370  46.2
# 247            0      165             90             33      680  52.3
# 248            9      124             70             33      402  35.4
# ...

# %%
sns.boxplot(data["Insulin"],data = data)

# %%
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 + (whisker_width*IQR)
data['Insulin'] = np.where(data['Insulin']>upper_whisker,upper_whisker,np.where(data['Insulin']<lower_whisker,lower_whisker,data['Insulin']))

# %%
sns.boxplot(data["Insulin"],data = data)

# %%
data.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35    0.000  33.6
# 1             1       85             66             29    0.000  26.6
# 2             8      183             64              0    0.000  23.3
# 3             1       89             66             23   94.000  28.1
# 4             0      137             40             35  168.000  43.1
# 5             5      116             74              0    0.000  25.6
# 6             3       78             50             32   88.000  31.0
# 7            10      115              0              0    0.000  35.3
# 8             2      197             70             45  318.125  30.5
# 9             8      125             96              0    0.000   0.0
# 10            4      110             92              0    0.000  37.6
# 11           10      168             74              0    0.000  38.0
# ...

# %%
x = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 82)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf')
classifier.fit(x_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[98  9]
#  [17 30]]
# 0.8311688311688312

# %%
i = 0
while i < 100:
    print(i)
    from sklearn.model_selection import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = i)
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    x_train = sc.fit_transform(x_train)
    x_test = sc.transform(x_test)
    from sklearn.svm import SVC
    classifier = SVC(kernel = 'rbf')
    classifier.fit(x_train, y_train)
    y_pred = classifier.predict(x_test)
    from sklearn.metrics import confusion_matrix, accuracy_score
    print(accuracy_score(y_test, y_pred))
    i = i + 1
# Out:
# 0
# 0.7987012987012987
# 1
# 0.7987012987012987
# 2
# 0.7532467532467533
# 3
# 0.7597402597402597
# 4
# 0.7662337662337663
# 5
# 0.7662337662337663
# 6
# 0.8051948051948052
# 7
# 0.8181818181818182
# 8
# 0.7922077922077922
# 9
# 0.7467532467532467
# 10
# 0.7402597402597403
# 11
# 0.7597402597402597
# 12
# 0.7987012987012987
# 13
# 0.7597402597402597
# 14
# 0.7142857142857143
# 15
# 0.7467532467532467
# 16
# 0.8181818181818182
# 17
# 0.7662337662337663
# 18
# 0.7467532467532467
# 19
# 0.7792207792207793
# 20
# 0.7532467532467533
# 21
# 0.7337662337662337
# 22
# 0.7207792207792207
# 23
# 0.7987012987012987
# 24
# 0.7142857142857143
# 25
# 0.7987012987012987
# 26
# 0.7792207792207793
# 27
# 0.7987012987012987
# 28
# 0.7857142857142857
# 29
# 0.7727272727272727
# 30
# 0.8116883116883117
# 31
# 0.7337662337662337
# 32
# 0.7857142857142857
# 33
# 0.7467532467532467
# 34
# 0.8181818181818182
# 35
# 0.7402597402597403
# 36
# 0.7467532467532467
# 37
# 0.7467532467532467
# 38
# ...
